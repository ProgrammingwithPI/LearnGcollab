# %% [markdown]
# <a href="https://colab.research.google.com/github/ProgrammingwithPI/LearnGcollab/blob/main/SAR_Proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install folium
import pandas as pd
from IPython.display import display


# Create a DataFrame with fake fire station data
data = pd.DataFrame({
    "Station": ["Station 1", "Station 2", "Station 3", "Station 4", "Station 5"],
    "Address": ["123 Main St", "456 Park Ave", "789 Elm St", "321 Oak St", "159 Maple St"],
    "Latitude": [36.1615, 36.1234, 36.1928, 36.1457, 36.1792],
    "Longitude": [-86.7845, -86.7012, -86.7592, -86.7741, -86.7095]
})
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: folium in /usr/local/lib/python3.8/dist-packages (0.13.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from folium) (1.21.6)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.8/dist-packages (from folium) (3.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from folium) (2.23.0)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in /usr/local/lib/python3.8/dist-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->folium) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->folium) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->folium) (2.10)

# %%
import folium
import geopy.distance

# %%
# Create a map with the geospatial data
map = folium.Map(location=[37.7197, -121.93324], zoom_start=12, tiles="cartodbpositron")

# Add the data to the map as markers
'''
for lat, lng, Station in zip(data.Latitude, data.Longitude, data.Station):
    folium.Marker(
        location=[lat, lng],
        icon=folium.Icon(color="red", icon="fire-extinguisher"),
        popup=Station
    ).add_to(map)
'''
# Display the map in the Google Colab noteobook
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_541b4144c6e44aa9c53e992659953f6b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_541b4144c6e44aa9c53e992659953f6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_541b4144c6e44aa9c53e992659953f6b = L.map(
#                 &quot;map_541b4144c6e44aa9c53e992659953f6b&quot;,
#                 {
#                     center: [37.7197, -121.93324],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9be1705eece56369deaa633db55371c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_541b4144c6e44aa9c53e992659953f6b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from itertools import combinations



for station_1, station_2 in combinations(data.index, 2):
    lat1, lng1 = data.loc[station_1, ["Latitude", "Longitude"]]
    lat2, lng2 = data.loc[station_2, ["Latitude", "Longitude"]]
    d = geopy.distance.vincenty((lat1, lng1), (lat2, lng2)).kilometers

    # Add a polyline to the map to represent the measured distance
    folium.PolyLine(
        locations=[(lat1, lng1), (lat2, lng2)],
        weight=2,
        label="Distance",
        color="yellow"
    ).add_to(map)

# Display the map in the Jupyter Notebook
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f58cf2383d27f54957750806fd671d74 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f58cf2383d27f54957750806fd671d74&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f58cf2383d27f54957750806fd671d74 = L.map(
#                 &quot;map_f58cf2383d27f54957750806fd671d74&quot;,
#                 {
#                     center: [36.1667, -86.7833],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4bf8aed9ecc7900935c77baf14e7482b = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f58cf2383d27f54957750806fd671d74);
#
#
#             var marker_65c256d0d93f14cf84de2e2c3e821fa0 = L.marker(
#                 [36.1615, -86.7845],
#                 {}
#             ).addTo(map_f58cf2383d27f54957750806fd671d74);
#
#
#             var icon_41a08f63920da7db980e440b1315ed50 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_65c256d0d93f14cf84de2e2c3e821fa0.setIcon(icon_41a08f63920da7db980e440b1315ed50);
#
#
#         var popup_5076048aeb90d4e9649562e80bc59966 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_38bfaaa22dae9e785f88460a36309d90 = $(`&lt;div id=&quot;html_38bfaaa22dae9e785f88460a36309d90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station 1&lt;/div&gt;`)[0];
#                 popup_5076048aeb90d4e9649562e80bc59966.setContent(html_38bfaaa22dae9e785f88460a36309d90);
#
#
#
#         marker_65c256d0d93f14cf84de2e2c3e821fa0.bindPopup(popup_5076048aeb90d4e9649562e80bc59966)
#         ;
#
#
#
#
#             var marker_ef7180c86ba399f28e5d76d54faae68d = L.marker(
#                 [36.1234, -86.7012],
#                 {}
#             ).addTo(map_f58cf2383d27f54957750806fd671d74);
#
#
#             var icon_dd94b160223fa7038b60cf0ec64960d8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ef7180c86ba399f28e5d76d54faae68d.setIcon(icon_dd94b160223fa7038b60cf0ec64960d8);
#
#
#         var popup_5c419fa91f72456e0247d451c53a842b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e813a3f168654875b2fe1d2099d34876 = $(`&lt;div id=&quot;html_e813a3f168654875b2fe1d2099d34876&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station 2&lt;/div&gt;`)[0];
#                 popup_5c419fa91f72456e0247d451c53a842b.setContent(html_e813a3f168654875b2fe1d2099d34876);
#
#
#
#         marker_ef7180c86ba399f28e5d76d54faae68d.bindPopup(popup_5c419fa91f72456e0247d451c53a842b)
#         ;
#
#
#
#
#             var marker_2e7263f85478b53b3b8250bfa8c90b6e = L.marker(
#                 [36.1928, -86.7592],
#                 {}
#             ).addTo(map_f58cf2383d27f54957750806fd671d74);
#
#
#             var icon_eff70cd1e16a99544ced3a2ff64c30bd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire-extinguisher&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2e7263f85478b53b3b8250bfa8c90b6e.setIcon(icon_eff70cd1e16a99544ced3a2ff64c30bd);
#
#
#         var popup_81e6a21a4167b387f32045b2b14d2219 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_573e727e0e57e1191cafd33b6c6d8d9c = $(`&lt;div id=&quot;html_573e727e0e57e1191cafd33b6c6d8d9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station 3&lt;/div&gt;`)[0];
#                 popup_81e6a21a4167b387f32045b2b14d2219.setContent(html_573e727e0e57e1191cafd33b6c6d8d9c);
#
#
#
#         marker_2e7263f85478b53b3b8250bfa8c90b6e.bindPopup(popup_81e6a21a4167b387f32045b2b14d2219)
#         ;
#
#
#
#
#             var marker_6c3b420870748cd4ad871adaca980517 = L.marker(
#                 [36.1457, -86.7741],
#                 {}
#             ).addTo(map_f58cf2383d27f54957750806fd671d74);
#
#
#             var icon_86aa07dbe908d0570b63664ca9e91115 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;ic

# %%
# Save the map to an HTML file
map.save("my_map.html")
